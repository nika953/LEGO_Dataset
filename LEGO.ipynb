# %%
import pandas as pd

# %%
lego = pd.read_csv('sets.csv')

# %%
lego
# Out:
#          Set_ID                     Name  Year      Theme    Theme_Group  \
# 0          75-1            PreSchool Set  1975  PreSchool     Pre-school
# 1          77-1            PreSchool Set  1975  PreSchool     Pre-school
# 2         077-1           Pre-School Set  1975      Duplo     Pre-school
# 3          78-1            PreSchool Set  1975  PreSchool     Pre-school
# 4          78-3                Basic Set  1975  Samsonite        Vintage
# ...         ...                      ...   ...        ...            ...
# 14931  854242-1        Creeper Key Chain  2023       Gear  Miscellaneous
# 14932  854243-1          Steve Key Chain  2023       Gear  Miscellaneous
# 14933  854244-1         Piglin Key Chain  2023       Gear  Miscellaneous
# 14934  854245-1   Fennec Shand Key Chain  2023       Gear  Miscellaneous
# 14935  854246-1  Scout Trooper Key Chain  2023       Gear  Miscellaneous
#
#                    Subtheme Category        Packaging  Num_Instructions  \
# ...

# %%
lego.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14936 entries, 0 to 14935
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Set_ID            14936 non-null  object
#  1   Name              14936 non-null  object
#  2   Year              14936 non-null  int64
#  3   Theme             14936 non-null  object
#  4   Theme_Group       14915 non-null  object
#  5   Subtheme          11495 non-null  object
#  6   Category          14936 non-null  object
#  7   Packaging         14936 non-null  object
#  8   Num_Instructions  14936 non-null  int64
#  9   Availability      14936 non-null  object
#  10  Pieces            13133 non-null  float64
#  11  Minifigures       7686 non-null   float64
#  12  Owned             14771 non-null  float64
#  13  Rating            14936 non-null  float64
#  14  USD_MSRP          5837 non-null   float64
#  15  Total_Quantity    12276 non-null  float64
# ...

# %%
lego[lego['Current_Price'].isna() == False]
# Out:
#          Set_ID                              Name  Year                Theme  \
# 36        659-1                     Police Patrol  1975             LEGOLAND
# 71        314-1                     Police Launch  1976             LEGOLAND
# 74        369-1               Coast Guard Station  1976             LEGOLAND
# 87        485-1                        Fire Truck  1976             LEGOLAND
# 174       787-1                     Storage Cloth  1977                Basic
# ...         ...                               ...   ...                  ...
# 14896   77015-1         Temple of the Golden Idol  2023        Indiana Jones
# 14897   80040-1           Monkie Kid's Combi Mech  2023           Monkie Kid
# 14908  112323-1        Master Wu vs. Ghost Archer  2023              Ninjago
# 14922  662302-1  Cave Explorer, Creeper and Slime  2023            Minecraft
# 14925  682303-1                     Miles Morales  2023  Marvel Super Heroes
#
# ...

# %% [markdown]
# ### Сгруппировать по Theme_Group и сравнить цену

# %%
lego['Theme'].unique()
# Out:
# array(['PreSchool', 'Duplo', 'Samsonite', 'Trains',
#        'Building Set with People', 'Books', 'LEGOLAND', 'Hobby Set',
#        'Gear', 'Universal Building Set', 'Basic', 'Dacta', 'Minitalia',
#        'Homemaker', 'Technic', 'Service Packs', 'Promotional', 'Town',
#        'Castle', 'Space', 'Fabuland', 'Scala', 'Education', 'Boats',
#        'Model Team', 'Assorted', 'Pirates', 'Belville', 'Creator',
#        'Freestyle', 'Primo', 'Aquazone', 'Time Cruisers', 'Western',
#        'Classic', 'Adventurers', 'Znap', 'Racers', 'Mindstorms',
#        'Seasonal', 'Rock Raiders', 'Star Wars', 'Studios', 'Baby',
#        'Action Wheelers', 'Sports', 'Bulk Bricks', 'Advanced models',
#        'Mickey Mouse', 'Bionicle', 'Jack Stone', 'Harry Potter',
#        'Dinosaurs', 'Alpha Team', 'Explore', 'Spybotics', 'Galidor',
#        'Miscellaneous', 'Island Xtreme Stunts', 'Clikits', 'World City',
#        '4 Juniors', 'Spider-Man', 'Discovery', 'Quatro',
# ...

# %%
lego[lego['Theme_Group'].isna() == True]
# Out:
#           Set_ID                             Name  Year              Theme  \
# 8255     55001-1               Nexus Force Rocket  2010      LEGO Universe
# 8383   2853944-1                  Nexus Astronaut  2010      LEGO Universe
# 14444    10785-1             Bakey with Cakey Fun  2023  Gabby's Dollhouse
# 14445    10786-1      Gabby & MerCat's Ship & Spa  2023  Gabby's Dollhouse
# 14446    10787-1       Kitty Fairy's Garden Party  2023  Gabby's Dollhouse
# 14447    10788-1                Gabby's Dollhouse  2023  Gabby's Dollhouse
# 14498    30629-1                     Finnius Dash  2023         LEGO Games
# 14499    30630-1                   Aquadirt Racer  2023         LEGO Games
# 14502    30636-1  Z-Blob and Bunchu Spider Escape  2023           Dreamzzz
# 14582    40657-1                    Dream Village  2023           Dreamzzz
# 14667    45495-1          Small Sorting Top Trays  2023        Educational
# ...

# %% [markdown]
# #### У нас есть всего 21 пропуск в Theme_Group и я заполнила его самым частым параметром

# %%
lego['Theme_Group'].value_counts()
# Out:
# Theme_Group
# Miscellaneous       3407
# Modern day          2228
# Licensed            2068
# Pre-school          1547
# Action/Adventure    1177
# Basic                827
# Model making         725
# Technical            594
# Constraction         491
# Historical           468
# Educational          435
# Racing               270
# Girls                240
# Junior               228
# Vintage              114
# Art and crafts        96
# Name: count, dtype: int64

# %%
lego['Theme_Group'] = lego['Theme_Group'].fillna('Miscellaneous')

# %%
theme = lego.groupby('Theme').agg({
    'Current_Price':['min','mean','median','max']
})
theme
# Out:
#                 Current_Price
#                           min        mean     median        max
# Theme
# 4 Juniors             13.2000   31.600000   31.60000    50.0000
# Action Wheelers           NaN         NaN        NaN        NaN
# Advanced models      135.0000  747.643015  474.47500  3099.9900
# Adventurers            7.0000  103.835600   54.23550   886.5000
# Agents                24.9900  124.536663   91.85585   325.0000
# ...                       ...         ...        ...        ...
# Western               25.0000  205.332500   77.00000   800.0000
# World City            13.5000   85.544386   61.46885   228.0000
# World Racers           5.7500   28.100067   29.20760    52.2591
# Xtra                   4.0000    5.831364    5.95000     8.9500
# Znap                   5.9725   17.986250    8.48625    49.0000
#
# [155 rows x 4 columns]

# %%
themegroup = lego.groupby('Theme_Group').agg({
    'Current_Price':['min','mean','median','max']
})
themegroup
# Out:
#                  Current_Price
#                            min        mean     median        max
# Theme_Group
# Action/Adventure        1.0000   87.133444   40.00000  1500.0000
# Art and crafts          0.7300   30.882232    5.00000   199.0000
# Basic                   0.0500   22.600684   10.00000   200.0000
# Constraction            4.3543   80.970243   49.25815   598.5000
# Educational             1.4749  133.753232   61.99500   795.0000
# Girls                   1.5000   57.785984   35.00000   260.0000
# Historical              4.4458  210.434185   80.00000  3000.0000
# Junior                  3.5000   32.721408   28.44000    80.0000
# Licensed                1.5000  112.382881   47.50000  5499.9900
# Miscellaneous           2.0000   44.876287   18.79000   499.9000
# Model making            3.0000  122.405318   40.00000  3099.9900
# Modern day              1.3410   64.486840   30.00000  1029.0000
# Pre-school              1.8627   36.467305   25.06650   183.9996
# ...

# %%
lego.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14936 entries, 0 to 14935
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Set_ID            14936 non-null  object
#  1   Name              14936 non-null  object
#  2   Year              14936 non-null  int64
#  3   Theme             14936 non-null  object
#  4   Theme_Group       14936 non-null  object
#  5   Subtheme          11495 non-null  object
#  6   Category          14936 non-null  object
#  7   Packaging         14936 non-null  object
#  8   Num_Instructions  14936 non-null  int64
#  9   Availability      14936 non-null  object
#  10  Pieces            13133 non-null  float64
#  11  Minifigures       7686 non-null   float64
#  12  Owned             14771 non-null  float64
#  13  Rating            14936 non-null  float64
#  14  USD_MSRP          5837 non-null   float64
#  15  Total_Quantity    12276 non-null  float64
# ...

# %%
lego.dropna(subset='Current_Price', inplace=True)

# %%
lego.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5442 entries, 36 to 14925
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Set_ID            5442 non-null   object
#  1   Name              5442 non-null   object
#  2   Year              5442 non-null   int64
#  3   Theme             5442 non-null   object
#  4   Theme_Group       5442 non-null   object
#  5   Subtheme          4763 non-null   object
#  6   Category          5442 non-null   object
#  7   Packaging         5442 non-null   object
#  8   Num_Instructions  5442 non-null   int64
#  9   Availability      5442 non-null   object
#  10  Pieces            5420 non-null   float64
#  11  Owned             5442 non-null   float64
#  12  Rating            5442 non-null   float64
#  13  Total_Quantity    5442 non-null   float64
#  14  Current_Price     5442 non-null   float64
# dtypes: float64(5), int64(2), object(8)
# memory usage: 680.2+ KB

# %%
del lego['Minifigures']

# %%
del lego['USD_MSRP']

# %%
lego[lego['Pieces'].isna() == True]
# Out:
#          Set_ID                           Name  Year                    Theme  \
# 3649     1524-1       Dino Island Pen Series 2  2000                     Gear
# 5459     7575-1        Clikits Advent Calendar  2004                  Clikits
# 6041   851499-1     Knights' Kingdom Chess Set  2005                     Gear
# 6403   851861-1              Vikings Chess Set  2006                     Gear
# 6900   852001-1               Castle Chess Set  2007                     Gear
# 6950   852132-1             Castle Tic Tac Toe  2007                     Gear
# 7779   852676-1               LEGO Travel Game  2009                     Gear
# 7816   852751-1              Pirates Chess Set  2009                     Gear
# 13333   71361-1                     Paragoomba  2020              Super Mario
# 13334   71361-2                          Fuzzy  2020              Super Mario
# 13862   71386-1                    Huckit Crab  2021              Super Mario
# ...

# %%
pack = lego.groupby('Packaging').agg({
    'Pieces':['min','mean','median','max']
})
pack
# Out:
#                       Pieces
#                          min        mean median      max
# Packaging
# Blister pack             4.0   58.075758   58.5    106.0
# Box                      0.0  446.684413  245.0  11695.0
# Box with backing card    6.0   68.629630   69.0    120.0
# Box with handle          9.0  208.100000   84.0   1500.0
# Canister                23.0   49.939394   45.0    233.0
# Foil pack                1.0   40.598131   38.0    193.0
# None (loose parts)      72.0  106.000000  106.0    140.0
# Other                    1.0   53.400000   33.0    403.0
# Paper bag                8.0    8.000000    8.0      8.0
# Plastic box              2.0  249.846154  273.0    544.0
# Plastic canister        15.0   47.400000   52.0     77.0
# Polybag                  1.0   40.107374   38.0    220.0
# Shrink-wrapped           1.0    1.500000    1.5      2.0
# Tub                     65.0  366.461538  326.0    790.0
# {Not specified}          1.0  109.930556   41.0   1417.0

# %%
def fill_nan_pieces(lego: pd.DataFrame, grouping_value: str, filling_value: str) -> pd.DataFrame:
    lego = lego.copy(deep=True)
    grouped = lego.groupby(grouping_value)[filling_value].mean()
    grouped.fillna(lego[filling_value].mean(), inplace=True)

    for value in lego[grouping_value].unique():
        indexes = list(lego[(lego[grouping_value] == value) & (lego[filling_value].isna() == True)].index)
        for index in indexes:
            lego.loc[[index], filling_value] = grouped[value]
    
    return lego

# %%
new_lego = fill_nan_pieces(lego, grouping_value='Packaging', filling_value='Pieces')

# %%
new_lego.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5442 entries, 36 to 14925
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Set_ID            5442 non-null   object
#  1   Name              5442 non-null   object
#  2   Year              5442 non-null   int64
#  3   Theme             5442 non-null   object
#  4   Theme_Group       5442 non-null   object
#  5   Subtheme          4763 non-null   object
#  6   Category          5442 non-null   object
#  7   Packaging         5442 non-null   object
#  8   Num_Instructions  5442 non-null   int64
#  9   Availability      5442 non-null   object
#  10  Pieces            5442 non-null   float64
#  11  Owned             5442 non-null   float64
#  12  Rating            5442 non-null   float64
#  13  Total_Quantity    5442 non-null   float64
#  14  Current_Price     5442 non-null   float64
# dtypes: float64(5), int64(2), object(8)
# memory usage: 809.3+ KB

# %%
new_lego[new_lego['Pieces'].isna() == True]
# Out:
# Empty DataFrame
# Columns: [Set_ID, Name, Year, Theme, Theme_Group, Subtheme, Category, Packaging, Num_Instructions, Availability, Pieces, Owned, Rating, Total_Quantity, Current_Price]
# Index: []
